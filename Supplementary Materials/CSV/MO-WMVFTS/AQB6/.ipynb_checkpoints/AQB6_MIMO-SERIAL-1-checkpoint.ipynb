# %%
import sys
sys.path.append("/home/hugo/projetos-doutorado/efts_multi_step/")
import numpy as np
import pandas as pd
from src.efts.models.mimo.onestep.ParallelMimoEFTS import ParallelMimoEFTS
from src.efts.util.DataSetUtil import DataSetUtil
from src.efts.util.MetricsUtil import MetricsUtil
from src.efts.util.StatisticsUtil import StatisticsUtil

# from pyFTS.partitioners.FCM import FCMPartitioner
# from pyFTS.partitioners.CMeans import CMeansPartitioner



np.seterr(divide='ignore', invalid='ignore')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Auxiliar Funcions

# %%
data_set_util = DataSetUtil()
metrics_util = MetricsUtil()
statistics_util = StatisticsUtil()

# %% [markdown]
# ## Global Variables

# %%
lags = 1
n_components = 4 
endogen_variable = None
time_variable = 'date' 
num_fuzzy_sets = 30
partitioner = None #CMeansPartitioner #FCMPartitioner # HuarngPartitioner
order = 1
gamma_kpca = 0.1
seasionality_vars = False
n_windows = 30
train_size = 0.75
plot_graph = False
target_variable =  endogen_variable
n_jobs = 8

# %% [markdown]
# ## AEC Data Set

# %%
time_step_ahead = 1

df = pd.read_csv('/home/hugo/projetos-doutorado/mimo_emb_fts/data/air/air_quality_beijing_6_sites.csv', sep=',')

df = df.drop(labels=['No','wd','station'], axis=1)
df = df.drop(labels=['No.1','day.1','year.1','month.1','hour.1','wd.1','station.1'], axis=1)
df = df.drop(labels=['No.2','day.2','year.2','month.2','hour.2','wd.2','station.2'], axis=1)
df = df.drop(labels=['No.3','day.3','year.3','month.3','hour.3','wd.3','station.3'], axis=1)
df = df.drop(labels=['No.4','day.4','year.4','month.4','hour.4','wd.4','station.4'], axis=1)
df = df.drop(labels=['No.5','day.5','year.5','month.5','hour.5','wd.5','station.5'], axis=1)

time = pd.to_datetime(df[['year', 'month', 'day', 'hour']])
df = data_set_util.clean_dataset(df.loc[:,'PM2.5':'WSPM.5'])

variables = df.loc[:,'PM2.5':'WSPM.5'].columns 

data = data_set_util.series_to_supervised_mimo(df.loc[:,'PM2.5':'WSPM.5'], 
                                               lags, time_step_ahead)
data['date'] = pd.to_datetime(time)
data.head(5)
# Out:
#     PM2.5(t)  PM10(t)  SO2(t)  NO2(t)  CO(t)  O3(t)  TEMP(t)  PRES(t)  \
# 24      24.0     24.0    26.0    54.0  600.0   36.0     -0.2   1030.5
# 25      22.0     24.0    24.0    44.0  500.0   44.0     -0.4   1031.0
# 29      14.0     17.0    21.0    36.0  400.0   50.0     -1.0   1031.3
# 31       9.0     11.0    19.0    70.0  500.0   20.0     -1.8   1030.1
# 32       3.0     11.0    34.0    58.0  500.0   27.0     -1.7   1029.8
#
#     DEWP(t)  RAIN(t)  ...  SO2.5(t+1)  NO2.5(t+1)  CO.5(t+1)  O3.5(t+1)  \
# 24    -17.4      0.0  ...        24.0        43.0     1399.0       25.0
# 25    -17.6      0.0  ...        25.0        28.0     1300.0       37.0
# 29    -17.3      0.0  ...        26.0        11.0     1200.0       50.0
# 31    -17.5      0.0  ...        19.0        11.0     1100.0       52.0
# 32    -17.0      0.0  ...        22.0        15.0     1200.0       51.0
#
#     TEMP.5(t+1)  PRES.5(t+1)  DEWP.5(t+1)  RAIN.5(t+1)  WSPM.5(t+1)  \
# 24         -0.3       1028.9        -18.0          0.0          1.4
# 25         -0.7       1029.2        -17.9          0.0          1.0
# 29         -1.3       1028.0        -18.4          0.0          1.4
# 31         -1.3       1028.0        -17.9          0.0          0.6
# 32         -0.6       1027.7        -17.8          0.0          0.9
#
#                   date
# 24 2013-03-02 00:00:00
# 25 2013-03-02 01:00:00
# 29 2013-03-02 05:00:00
# 31 2013-03-02 07:00:00
# 32 2013-03-02 08:00:00
#
# [5 rows x 133 columns]

# %%
#data.to_csv (r'/home/hugo/projetos-doutorado/efts_multi_step/Notebooks/mimo_experiments/ONE-STEP/data/AQB6.csv', index = False, header=True)

# %% [markdown]
# ## MIMO One step ahead method

# %%
first_col_test = 'PM2.5(t)' 
last_col_test = 'WSPM.5(t)' 
last_col_test = 'date'
first_col_test_val = 'PM2.5(t+1)' 
last_col_test_val = 'WSPM.5(t+1)' 
time_steps =  time_step_ahead
vars_vector = data.loc[:,'PM2.5(t+1)':'WSPM.5(t+1)'].columns
vars_vector_test = data.loc[:,'PM2.5(t+1)':'WSPM.5(t+1)'].columns

# %%
efts_multi_step = ParallelMimoEFTS(n_components = n_components, endogen_variable = endogen_variable, 
                                    time_variable = time_variable, num_fuzzy_sets = num_fuzzy_sets, 
                                    partitioner = partitioner, order = order, steps_ahead = time_step_ahead, 
                                    gamma_kpca = gamma_kpca, seasionality_vars = seasionality_vars,
                                    vars_vector = vars_vector,n_jobs = n_jobs,vars_vector_test = vars_vector_test)
# Out:
# Number of processors:  8
# Number of jobs:  8

# %% [markdown]
# ## Sliding window cross validation

# %% [markdown]
# ### Embedding Transformation = PCA

# %%
# transformation = 'PCA'

# %%
# final_metrics_measures_pca, metrics_measures_pca = statistics_util.sliding_windows_mimo_2(data = data, n_windows = n_windows, train_size= train_size, 
#                                                         efts_model = efts_multi_step, transformation = transformation, 
#                                                         first_col_test = first_col_test, last_col_test = last_col_test,
#                                                         first_col_test_val = first_col_test_val, last_col_test_val = last_col_test_val,
#                                                         time_steps = time_steps, target_variable = target_variable, 
#                                                         plot_graph = plot_graph, vars_vector = vars_vector)

# %%
# pd.set_option('display.max_rows', None)
# metrics_measures_pca.head(20)

# %%
# final_metrics_measures_pca

# %%
# metrics_measures_pca.to_csv (r'aec_metrics_measures_pca_parallel.csv', index = False, header=True)
# final_metrics_measures_pca.to_csv (r'aec_final_metrics_measures_pca_parallel.csv', index = False, header=True)

# %% [markdown]
# ### Embedding Transformation = KPCA

# %%
transformation = 'KPCA'

# %%
final_metrics_measures_kpca, metrics_measures_kpca = statistics_util.sliding_windows_mimo_2(data = data, n_windows = n_windows, train_size= train_size, 
                                                        efts_model = efts_multi_step, transformation = transformation, 
                                                        first_col_test = first_col_test, last_col_test = last_col_test,
                                                        first_col_test_val = first_col_test_val, last_col_test_val = last_col_test,
                                                        time_steps = time_steps, target_variable = target_variable, 
                                                        plot_graph = plot_graph, vars_vector = vars_vector)
# Out:
# windows length = 774
# --------------------
#
#  ===> Training window 0
#
# Start method learning.
#
# PM2.5(t+1) model (learning)PM10(t+1) model (learning)
#
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)CO(t+1) model (learning)
# O3(t+1) model (learning)
#
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)
# RAIN(t+1) model (learning)
# WSPM(t+1) model (learning)
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)
# SO2.1(t+1) model (learning)
# NO2.1(t+1) model (learning)
# CO.1(t+1) model (learning)
# O3.1(t+1) model (learning)
# TEMP.1(t+1) model (learning)
# PRES.1(t+1) model (learning)
# DEWP.1(t+1) model (learning)
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)PM2.5.2(t+1) model (learning)
#
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)
# CO.2(t+1) model (learning)O3.2(t+1) model (learning)
#
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)
# RAIN.2(t+1) model (learning)
# WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)
# NO2.3(t+1) model (learning)
# CO.3(t+1) model (learning)
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)
# RAIN.3(t+1) model (learning)
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)
# WSPM.4(t+1) model (learning)
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)
#
# PRES.5(t+1) model (learning)
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
#  62.9 secs
#  62.9 secs   0.7 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as target
# PM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
# SO2(t+1) --> forecasting NO2(t+1) --> forecasting
#
# SO2(t)---> input this variable as target
# CO(t+1) --> forecasting
# NO2(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
# CO(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting
# PM2.5.1(t)---> input this variable as target
# PM10.1(t+1) --> forecasting
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as target
# PM10.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# TEMP.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# TEMP.3(t+1) --> forecasting O3.3(t)---> input this variable as target
#
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# SO2.5(t+1) --> forecasting PM10.5(t)---> input this variable as target
#
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as targetWSPM.5(t+1) --> forecasting
#
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  19.4 secs
#  19.4 secs   0.7 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 774
#
# Start method learning.
#
# PM2.5(t+1) model (learning)
# PM10(t+1) model (learning)
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)
# CO(t+1) model (learning)O3(t+1) model (learning)
#
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)
# RAIN(t+1) model (learning)WSPM(t+1) model (learning)
#
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)
# SO2.1(t+1) model (learning)
# NO2.1(t+1) model (learning)
# CO.1(t+1) model (learning)
# O3.1(t+1) model (learning)
# TEMP.1(t+1) model (learning)
# PRES.1(t+1) model (learning)
# DEWP.1(t+1) model (learning)
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)
# PM2.5.2(t+1) model (learning)
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)
# CO.2(t+1) model (learning)
# O3.2(t+1) model (learning)
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)
# RAIN.2(t+1) model (learning)
# WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)
# NO2.3(t+1) model (learning)
# CO.3(t+1) model (learning)
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)RAIN.3(t+1) model (learning)
#
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)TEMP.4(t+1) model (learning)
#
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)
# WSPM.4(t+1) model (learning)
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)
# PRES.5(t+1) model (learning)
# DEWP.5(t+1) model (learning)RAIN.5(t+1) model (learning)
#
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
#  66.5 secs
#  66.5 secs   1.1 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as targetPM10(t+1) --> forecasting SO2(t+1) --> forecasting
#
# PM10(t)---> input this variable as target
# NO2(t+1) --> forecasting
# NO2(t)---> input this variable as target
# CO(t+1) --> forecasting
# CO(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
#
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# SO2(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting PM10.1(t+1) --> forecasting
# PM10.1(t)---> input this variable as target
#
# PM2.5.1(t)---> input this variable as target
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
#
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
#
# O3.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
#
# DEWP.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting WSPM.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
#
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
# SO2.5(t+1) --> forecasting
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  19.4 secs
#  19.4 secs   1.1 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 1548
#
# Start method learning.
#
# PM2.5(t+1) model (learning)PM10(t+1) model (learning)
# SO2(t+1) model (learning)
#
# NO2(t+1) model (learning)
# CO(t+1) model (learning)
# O3(t+1) model (learning)
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)
# RAIN(t+1) model (learning)
# WSPM(t+1) model (learning)
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)
# SO2.1(t+1) model (learning)
# NO2.1(t+1) model (learning)
# CO.1(t+1) model (learning)
# O3.1(t+1) model (learning)
# TEMP.1(t+1) model (learning)
# PRES.1(t+1) model (learning)
# DEWP.1(t+1) model (learning)
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)
# PM2.5.2(t+1) model (learning)
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)
# CO.2(t+1) model (learning)
# O3.2(t+1) model (learning)
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)
# RAIN.2(t+1) model (learning)WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
#
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)NO2.3(t+1) model (learning)
#
# CO.3(t+1) model (learning)
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)
# RAIN.3(t+1) model (learning)
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)
# WSPM.4(t+1) model (learning)
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)
# PRES.5(t+1) model (learning)
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
#  68.0 secs
#  68.0 secs   1.1 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as target
# PM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
# SO2(t+1) --> forecasting
# SO2(t)---> input this variable as target
# NO2(t+1) --> forecasting
# NO2(t)---> input this variable as target
# CO(t+1) --> forecasting
# CO(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting PM2.5.1(t+1) --> forecasting
# PM2.5.1(t)---> input this variable as target
#
# WSPM(t)---> input this variable as target
# PM10.1(t+1) --> forecasting SO2.1(t+1) --> forecasting
# PM10.1(t)---> input this variable as target
#
# SO2.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# TEMP.1(t+1) --> forecasting O3.1(t)---> input this variable as target
#
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# NO2.2(t+1) --> forecasting SO2.2(t)---> input this variable as target
#
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# O3.3(t)---> input this variable as target
# TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
# SO2.5(t+1) --> forecasting
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  21.6 secs
#  21.6 secs   1.1 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 2322
#
# Start method learning.
#
# PM2.5(t+1) model (learning)
# PM10(t+1) model (learning)
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)
# CO(t+1) model (learning)
# O3(t+1) model (learning)
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)
# RAIN(t+1) model (learning)
# WSPM(t+1) model (learning)
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)
# SO2.1(t+1) model (learning)
# NO2.1(t+1) model (learning)CO.1(t+1) model (learning)
#
# O3.1(t+1) model (learning)
# TEMP.1(t+1) model (learning)
# PRES.1(t+1) model (learning)DEWP.1(t+1) model (learning)
#
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)
# PM2.5.2(t+1) model (learning)
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)CO.2(t+1) model (learning)
# O3.2(t+1) model (learning)
#
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)RAIN.2(t+1) model (learning)
#
# WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)
# NO2.3(t+1) model (learning)
# CO.3(t+1) model (learning)
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)PRES.3(t+1) model (learning)
#
# DEWP.3(t+1) model (learning)
# RAIN.3(t+1) model (learning)
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)DEWP.4(t+1) model (learning)
#
# RAIN.4(t+1) model (learning)
# WSPM.4(t+1) model (learning)
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)
# PRES.5(t+1) model (learning)
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
#  67.5 secs
#  67.5 secs   1.1 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as target
# PM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
# SO2(t+1) --> forecasting
# SO2(t)---> input this variable as target
# NO2(t+1) --> forecasting
# NO2(t)---> input this variable as target
# CO(t+1) --> forecasting
# CO(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting PM10.1(t+1) --> forecasting
# PM10.1(t)---> input this variable as target
#
# PM2.5.1(t)---> input this variable as target
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# O3.3(t)---> input this variable as target
# TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
# SO2.5(t+1) --> forecasting
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  19.9 secs
#  19.9 secs   1.1 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 3096
#
# Start method learning.
#
# PM2.5(t+1) model (learning)
# PM10(t+1) model (learning)
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)
# CO(t+1) model (learning)
# O3(t+1) model (learning)
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)RAIN(t+1) model (learning)WSPM(t+1) model (learning)
#
#
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)
# SO2.1(t+1) model (learning)
# NO2.1(t+1) model (learning)
# CO.1(t+1) model (learning)
# O3.1(t+1) model (learning)
# TEMP.1(t+1) model (learning)
# PRES.1(t+1) model (learning)
# DEWP.1(t+1) model (learning)
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)
# PM2.5.2(t+1) model (learning)
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)
# CO.2(t+1) model (learning)
# O3.2(t+1) model (learning)
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)
# RAIN.2(t+1) model (learning)
# WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)
# NO2.3(t+1) model (learning)
# CO.3(t+1) model (learning)
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)
# RAIN.3(t+1) model (learning)
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)
# WSPM.4(t+1) model (learning)
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)PRES.5(t+1) model (learning)
#
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
#  69.8 secs
#  69.8 secs   1.1 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as targetPM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
#
# SO2(t+1) --> forecasting
# SO2(t)---> input this variable as target
# NO2(t+1) --> forecasting
# NO2(t)---> input this variable as targetCO(t+1) --> forecasting
# CO(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
#
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting
# PM2.5.1(t)---> input this variable as target
# PM10.1(t+1) --> forecasting
# PM10.1(t)---> input this variable as target
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# O3.3(t)---> input this variable as target
# TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
# SO2.5(t+1) --> forecasting
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  20.3 secs
#  20.3 secs   1.1 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 3870
#
# Start method learning.
#
# PM2.5(t+1) model (learning)
# PM10(t+1) model (learning)
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)
# CO(t+1) model (learning)
# O3(t+1) model (learning)
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)
# RAIN(t+1) model (learning)
# WSPM(t+1) model (learning)
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)
# SO2.1(t+1) model (learning)
# NO2.1(t+1) model (learning)
# CO.1(t+1) model (learning)
# O3.1(t+1) model (learning)
# TEMP.1(t+1) model (learning)
# PRES.1(t+1) model (learning)
# DEWP.1(t+1) model (learning)
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)
# PM2.5.2(t+1) model (learning)
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)
# CO.2(t+1) model (learning)
# O3.2(t+1) model (learning)
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)
# RAIN.2(t+1) model (learning)
# WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)
# NO2.3(t+1) model (learning)
# CO.3(t+1) model (learning)O3.3(t+1) model (learning)
#
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)
# RAIN.3(t+1) model (learning)
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)WSPM.4(t+1) model (learning)
#
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)
# PRES.5(t+1) model (learning)
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)WSPM.5(t+1) model (learning)
#
#
# End method learning.
#
#  68.9 secs
#  68.9 secs   1.1 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as target
# PM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
# SO2(t+1) --> forecasting
# SO2(t)---> input this variable as target
# NO2(t+1) --> forecasting
# NO2(t)---> input this variable as target
# CO(t+1) --> forecasting
# CO(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as targetPRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
#
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting
# PM10.1(t+1) --> forecasting PM2.5.1(t)---> input this variable as target
# PM10.1(t)---> input this variable as target
#
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as targetSO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
#
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# O3.3(t)---> input this variable as target
# TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
#
# TEMP.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
# SO2.5(t+1) --> forecasting
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  21.7 secs
#  21.7 secs   1.1 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 4644
#
# Start method learning.
#
# PM2.5(t+1) model (learning)
# PM10(t+1) model (learning)
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)
# CO(t+1) model (learning)
# O3(t+1) model (learning)
# TEMP(t+1) model (learning)
# PRES(t+1) model (learning)
# DEWP(t+1) model (learning)
# RAIN(t+1) model (learning)
# WSPM(t+1) model (learning)
# PM2.5.1(t+1) model (learning)
# PM10.1(t+1) model (learning)SO2.1(t+1) model (learning)
#
# NO2.1(t+1) model (learning)
# CO.1(t+1) model (learning)
# O3.1(t+1) model (learning)TEMP.1(t+1) model (learning)
#
# PRES.1(t+1) model (learning)
# DEWP.1(t+1) model (learning)
# RAIN.1(t+1) model (learning)
# WSPM.1(t+1) model (learning)
# PM2.5.2(t+1) model (learning)
# PM10.2(t+1) model (learning)
# SO2.2(t+1) model (learning)
# NO2.2(t+1) model (learning)
# CO.2(t+1) model (learning)
# O3.2(t+1) model (learning)
# TEMP.2(t+1) model (learning)
# PRES.2(t+1) model (learning)
# DEWP.2(t+1) model (learning)
# RAIN.2(t+1) model (learning)
# WSPM.2(t+1) model (learning)
# PM2.5.3(t+1) model (learning)
# PM10.3(t+1) model (learning)
# SO2.3(t+1) model (learning)
# NO2.3(t+1) model (learning)
# CO.3(t+1) model (learning)
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)
# RAIN.3(t+1) model (learning)
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)O3.4(t+1) model (learning)
#
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)
# WSPM.4(t+1) model (learning)
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)PRES.5(t+1) model (learning)
#
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
# 100.7 secs
# 100.7 secs   1.1 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting
# PM2.5(t)---> input this variable as target
# PM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
# SO2(t+1) --> forecasting NO2(t+1) --> forecasting
# NO2(t)---> input this variable as target
# CO(t+1) --> forecasting
# CO(t)---> input this variable as target
# O3(t+1) --> forecasting
# O3(t)---> input this variable as target
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
#
# SO2(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting
# PM2.5.1(t)---> input this variable as target
# PM10.1(t+1) --> forecasting
# PM10.1(t)---> input this variable as target
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as target
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# O3.3(t)---> input this variable as target
# TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
# SO2.5(t+1) --> forecasting
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  42.4 secs
#  42.4 secs   1.1 MByte
# time_steps: 1
# --------------------
#
#  ===> Training window 5418
#
# Start method learning.
#
# PM2.5(t+1) model (learning)
# PM10(t+1) model (learning)
# SO2(t+1) model (learning)
# NO2(t+1) model (learning)
# CO(t+1) model (learning)
# O3(t+1) model (learning)
# TEMP(t+1) model (learning)
# ...
# O3.3(t+1) model (learning)
# TEMP.3(t+1) model (learning)
# PRES.3(t+1) model (learning)
# DEWP.3(t+1) model (learning)RAIN.3(t+1) model (learning)
#
# WSPM.3(t+1) model (learning)
# PM2.5.4(t+1) model (learning)
# PM10.4(t+1) model (learning)
# SO2.4(t+1) model (learning)
# NO2.4(t+1) model (learning)
# CO.4(t+1) model (learning)
# O3.4(t+1) model (learning)
# TEMP.4(t+1) model (learning)
# PRES.4(t+1) model (learning)
# DEWP.4(t+1) model (learning)
# RAIN.4(t+1) model (learning)WSPM.4(t+1) model (learning)
#
# PM2.5.5(t+1) model (learning)
# PM10.5(t+1) model (learning)
# SO2.5(t+1) model (learning)
# NO2.5(t+1) model (learning)
# CO.5(t+1) model (learning)
# O3.5(t+1) model (learning)
# TEMP.5(t+1) model (learning)
# PRES.5(t+1) model (learning)
# DEWP.5(t+1) model (learning)
# RAIN.5(t+1) model (learning)
# WSPM.5(t+1) model (learning)
#
# End method learning.
#
# 3110.1 secs
# 1083.1 secs   6.7 MByte
#
# Start method forecasting.
#
# PM2.5(t+1) --> forecasting PM10(t+1) --> forecasting
# PM10(t)---> input this variable as target
#
# PM2.5(t)---> input this variable as target
# SO2(t+1) --> forecasting
# SO2(t)---> input this variable as target
# NO2(t+1) --> forecasting
# NO2(t)---> input this variable as target
# CO(t+1) --> forecasting O3(t+1) --> forecasting
# O3(t)---> input this variable as target
#
# CO(t)---> input this variable as target
# TEMP(t+1) --> forecasting
# TEMP(t)---> input this variable as target
# PRES(t+1) --> forecasting
# PRES(t)---> input this variable as target
# DEWP(t+1) --> forecasting
# DEWP(t)---> input this variable as target
# RAIN(t+1) --> forecasting
# RAIN(t)---> input this variable as target
# WSPM(t+1) --> forecasting
# WSPM(t)---> input this variable as target
# PM2.5.1(t+1) --> forecasting
# PM2.5.1(t)---> input this variable as target
# PM10.1(t+1) --> forecasting
# SO2.1(t+1) --> forecasting
# SO2.1(t)---> input this variable as targetPM10.1(t)---> input this variable as target
#
# NO2.1(t+1) --> forecasting
# NO2.1(t)---> input this variable as target
# CO.1(t+1) --> forecasting
# CO.1(t)---> input this variable as target
# O3.1(t+1) --> forecasting
# O3.1(t)---> input this variable as target
# TEMP.1(t+1) --> forecasting
# TEMP.1(t)---> input this variable as target
# PRES.1(t+1) --> forecasting
# PRES.1(t)---> input this variable as target
# DEWP.1(t+1) --> forecasting
# DEWP.1(t)---> input this variable as target
# RAIN.1(t+1) --> forecasting
# RAIN.1(t)---> input this variable as target
# WSPM.1(t+1) --> forecasting
# WSPM.1(t)---> input this variable as target
# PM2.5.2(t+1) --> forecasting
# PM2.5.2(t)---> input this variable as target
# PM10.2(t+1) --> forecasting
# PM10.2(t)---> input this variable as target
# SO2.2(t+1) --> forecasting
# SO2.2(t)---> input this variable as target
# NO2.2(t+1) --> forecasting
# NO2.2(t)---> input this variable as target
# CO.2(t+1) --> forecasting
# CO.2(t)---> input this variable as target
# O3.2(t+1) --> forecasting
# O3.2(t)---> input this variable as target
# TEMP.2(t+1) --> forecasting
# TEMP.2(t)---> input this variable as target
# PRES.2(t+1) --> forecasting
# PRES.2(t)---> input this variable as target
# DEWP.2(t+1) --> forecasting
# DEWP.2(t)---> input this variable as target
# RAIN.2(t+1) --> forecasting
# RAIN.2(t)---> input this variable as target
# WSPM.2(t+1) --> forecasting
# WSPM.2(t)---> input this variable as target
# PM2.5.3(t+1) --> forecasting
# PM2.5.3(t)---> input this variable as target
# PM10.3(t+1) --> forecasting
# PM10.3(t)---> input this variable as target
# SO2.3(t+1) --> forecasting
# SO2.3(t)---> input this variable as target
# NO2.3(t+1) --> forecasting
# NO2.3(t)---> input this variable as target
# CO.3(t+1) --> forecasting
# CO.3(t)---> input this variable as target
# O3.3(t+1) --> forecasting
# O3.3(t)---> input this variable as target
# TEMP.3(t+1) --> forecasting
# TEMP.3(t)---> input this variable as target
# PRES.3(t+1) --> forecasting
# PRES.3(t)---> input this variable as target
# DEWP.3(t+1) --> forecasting
# DEWP.3(t)---> input this variable as target
# RAIN.3(t+1) --> forecasting
# RAIN.3(t)---> input this variable as target
# WSPM.3(t+1) --> forecasting
# WSPM.3(t)---> input this variable as target
# PM2.5.4(t+1) --> forecasting
# PM2.5.4(t)---> input this variable as target
# PM10.4(t+1) --> forecasting
# PM10.4(t)---> input this variable as target
# SO2.4(t+1) --> forecasting
# SO2.4(t)---> input this variable as target
# NO2.4(t+1) --> forecasting
# NO2.4(t)---> input this variable as target
# CO.4(t+1) --> forecasting
# CO.4(t)---> input this variable as target
# O3.4(t+1) --> forecasting
# O3.4(t)---> input this variable as target
# TEMP.4(t+1) --> forecasting
# TEMP.4(t)---> input this variable as target
# PRES.4(t+1) --> forecasting
# PRES.4(t)---> input this variable as target
# DEWP.4(t+1) --> forecasting
# DEWP.4(t)---> input this variable as target
# RAIN.4(t+1) --> forecasting
# RAIN.4(t)---> input this variable as target
# WSPM.4(t+1) --> forecasting
# WSPM.4(t)---> input this variable as target
# PM2.5.5(t+1) --> forecasting
# PM2.5.5(t)---> input this variable as target
# PM10.5(t+1) --> forecasting SO2.5(t+1) --> forecasting
# PM10.5(t)---> input this variable as target
#
# SO2.5(t)---> input this variable as target
# NO2.5(t+1) --> forecasting
# NO2.5(t)---> input this variable as target
# CO.5(t+1) --> forecasting
# CO.5(t)---> input this variable as target
# O3.5(t+1) --> forecasting
# O3.5(t)---> input this variable as target
# TEMP.5(t+1) --> forecasting
# TEMP.5(t)---> input this variable as target
# PRES.5(t+1) --> forecasting
# PRES.5(t)---> input this variable as target
# DEWP.5(t+1) --> forecasting
# DEWP.5(t)---> input this variable as target
# RAIN.5(t+1) --> forecasting
# RAIN.5(t)---> input this variable as target
# WSPM.5(t+1) --> forecasting
# WSPM.5(t)---> input this variable as target
#
# End method forecasting.
#
#  42.8 secs
#  42.8 secs   6.7 MByte
# time_steps: 1
# Final Results (AVG): ('PM2.5(t+1)', 1.051, 5.443, 1.175, 0.506, 0.005, 0.86)
# Final Results (STD): ('PM2.5(t+1)', 0.898, 12.303, 1.684, 0.664, 0.005, 0.273)
# Final Results (AVG): ('PM10(t+1)', 2.037, 6.173, 1.256, 0.528, 0.007, 0.873)
# Final Results (STD): ('PM10(t+1)', 1.162, 14.1, 1.228, 0.498, 0.006, 0.262)
# Final Results (AVG): ('SO2(t+1)', 0.257, 0.433, 1.115, 0.471, 0.008, 0.934)
# Final Results (STD): ('SO2(t+1)', 0.237, 1.236, 1.124, 0.433, 0.01, 0.178)
# Final Results (AVG): ('NO2(t+1)', 0.762, 0.649, 0.472, 0.203, 0.006, 0.974)
# Final Results (STD): ('NO2(t+1)', 0.507, 1.926, 0.606, 0.205, 0.004, 0.098)
# Final Results (AVG): ('CO(t+1)', 15.354, 34.334, 0.905, 0.333, 0.005, 0.917)
# Final Results (STD): ('CO(t+1)', 13.965, 92.224, 1.596, 0.424, 0.004, 0.183)
# Final Results (AVG): ('O3(t+1)', 0.978, 48.5, 3.006, 0.98, 0.006, 0.918)
# Final Results (STD): ('O3(t+1)', 0.644, 258.979, 5.595, 1.629, 0.004, 0.22)
# Final Results (AVG): ('TEMP(t+1)', 44.457, 122.54, inf, 4.109, 2.386, -1392.872)
# Final Results (STD): ('TEMP(t+1)', 157.937, 590.2, nan, 9.523, 9.161, 5399.852)
# Final Results (AVG): ('PRES(t+1)', 77.31, 16.801, 1.642, 0.203, 2.252, -2284.217)
# Final Results (STD): ('PRES(t+1)', 420.435, 90.855, 8.879, 1.053, 12.148, 12516.477)
# Final Results (AVG): ('DEWP(t+1)', 0.092, 0.82, inf, 0.317, 0.005, 0.787)
# Final Results (STD): ('DEWP(t+1)', 0.055, 1.97, nan, 0.636, 0.003, 0.395)
# Final Results (AVG): ('RAIN(t+1)', 0.016, 0.023, nan, nan, 0.013, 0.501)
# Final Results (STD): ('RAIN(t+1)', 0.023, 0.052, nan, nan, 0.031, 0.525)
# Final Results (AVG): ('WSPM(t+1)', 0.055, 0.02, inf, 1.305, 0.011, 0.97)
# Final Results (STD): ('WSPM(t+1)', 0.037, 0.032, nan, 2.969, 0.01, 0.083)
# Final Results (AVG): ('PM2.5.1(t+1)', 0.956, 3.189, 1.327, 0.568, 0.005, 0.912)
# Final Results (STD): ('PM2.5.1(t+1)', 0.66, 8.984, 1.969, 0.764, 0.004, 0.216)
# Final Results (AVG): ('PM10.1(t+1)', 1.971, 3.747, 1.102, 0.511, 0.007, 0.905)
# Final Results (STD): ('PM10.1(t+1)', 1.401, 9.47, 1.258, 0.566, 0.006, 0.21)
# Final Results (AVG): ('SO2.1(t+1)', 0.369, 0.464, 2.999, 1.066, 0.01, 0.879)
# Final Results (STD): ('SO2.1(t+1)', 0.272, 1.352, 5.814, 1.597, 0.01, 0.24)
# Final Results (AVG): ('NO2.1(t+1)', 0.661, 0.401, 0.856, 0.342, 0.006, 0.974)
# Final Results (STD): ('NO2.1(t+1)', 0.384, 1.17, 0.977, 0.319, 0.004, 0.101)
# Final Results (AVG): ('CO.1(t+1)', 23.045, 24.399, 0.9, 0.403, 0.007, 0.925)
# Final Results (STD): ('CO.1(t+1)', 30.098, 45.078, 0.967, 0.406, 0.007, 0.167)
# Final Results (AVG): ('O3.1(t+1)', 0.894, 68.368, 1.534, 0.583, 0.006, 0.922)
# Final Results (STD): ('O3.1(t+1)', 0.675, 370.143, 2.023, 0.625, 0.004, 0.204)
# Final Results (AVG): ('TEMP.1(t+1)', 34.223, 66.124, inf, 3.948, 1.475, -603.916)
# Final Results (STD): ('TEMP.1(t+1)', 116.753, 285.462, nan, 9.853, 5.824, 2541.43)
# Final Results (AVG): ('PRES.1(t+1)', 0.531, 0.206, 0.02, 0.01, 0.033, 0.97)
# Final Results (STD): ('PRES.1(t+1)', 0.227, 0.117, 0.012, 0.006, 0.019, 0.034)
# Final Results (AVG): ('DEWP.1(t+1)', 0.073, 0.777, inf, 0.542, 0.004, 0.814)
# Final Results (STD): ('DEWP.1(t+1)', 0.065, 2.18, nan, 1.02, 0.003, 0.404)
# Final Results (AVG): ('RAIN.1(t+1)', 0.018, 0.009, nan, nan, 0.007, 0.606)
# Final Results (STD): ('RAIN.1(t+1)', 0.037, 0.019, nan, nan, 0.023, 0.598)
# Final Results (AVG): ('WSPM.1(t+1)', 0.059, 0.021, inf, 0.621, 0.01, 0.969)
# Final Results (STD): ('WSPM.1(t+1)', 0.037, 0.026, nan, 0.397, 0.007, 0.104)
# Final Results (AVG): ('PM2.5.2(t+1)', 1.437, 4.506, 1.537, 0.624, 0.007, 0.884)
# Final Results (STD): ('PM2.5.2(t+1)', 2.415, 11.944, 2.218, 0.822, 0.015, 0.266)
# Final Results (AVG): ('PM10.2(t+1)', 1.946, 3.641, 1.675, 0.66, 0.009, 0.896)
# Final Results (STD): ('PM10.2(t+1)', 1.335, 9.746, 2.188, 0.722, 0.011, 0.219)
# Final Results (AVG): ('SO2.2(t+1)', 0.272, 0.247, 3.059, 1.061, 0.008, 0.931)
# Final Results (STD): ('SO2.2(t+1)', 0.258, 0.766, 9.356, 2.491, 0.008, 0.175)
# Final Results (AVG): ('NO2.2(t+1)', 0.382, 0.706, 0.989, 0.406, 0.005, 0.942)
# Final Results (STD): ('NO2.2(t+1)', 0.279, 2.399, 1.818, 0.588, 0.004, 0.162)
# Final Results (AVG): ('CO.2(t+1)', 16.256, 23.766, 1.025, 0.462, 0.006, 0.913)
# Final Results (STD): ('CO.2(t+1)', 14.595, 42.831, 1.331, 0.543, 0.005, 0.169)
# Final Results (AVG): ('O3.2(t+1)', 0.91, 94.844, 0.912, 0.395, 0.006, 0.941)
# Final Results (STD): ('O3.2(t+1)', 0.718, 516.043, 1.339, 0.517, 0.006, 0.198)
# Final Results (AVG): ('TEMP.2(t+1)', 34.223, 66.124, inf, 3.948, 1.475, -603.916)
# Final Results (STD): ('TEMP.2(t+1)', 116.753, 285.462, nan, 9.853, 5.824, 2541.43)
# Final Results (AVG): ('PRES.2(t+1)', 77.094, 16.865, 1.657, 0.207, 2.252, -2252.285)
# Final Results (STD): ('PRES.2(t+1)', 419.304, 91.221, 8.959, 1.077, 12.15, 12341.579)
# Final Results (AVG): ('DEWP.2(t+1)', 0.073, 0.777, inf, 0.542, 0.004, 0.814)
# Final Results (STD): ('DEWP.2(t+1)', 0.065, 2.18, nan, 1.02, 0.003, 0.404)
# Final Results (AVG): ('RAIN.2(t+1)', 0.018, 0.009, nan, nan, 0.007, 0.606)
# Final Results (STD): ('RAIN.2(t+1)', 0.037, 0.019, nan, nan, 0.023, 0.598)
# Final Results (AVG): ('WSPM.2(t+1)', 0.055, 0.021, inf, 0.593, 0.009, 0.97)
# Final Results (STD): ('WSPM.2(t+1)', 0.03, 0.025, nan, 0.356, 0.006, 0.103)
# Final Results (AVG): ('PM2.5.3(t+1)', 1.235, 4.836, 1.44, 0.567, 0.005, 0.887)
# Final Results (STD): ('PM2.5.3(t+1)', 1.314, 11.912, 2.482, 0.841, 0.006, 0.261)
# Final Results (AVG): ('PM10.3(t+1)', 2.127, 4.622, 1.424, 0.535, 0.007, 0.9)
# Final Results (STD): ('PM10.3(t+1)', 1.587, 9.391, 2.022, 0.644, 0.006, 0.211)
# Final Results (AVG): ('SO2.3(t+1)', 0.295, 0.481, 1.504, 0.625, 0.007, 0.927)
# Final Results (STD): ('SO2.3(t+1)', 0.307, 1.226, 2.118, 0.794, 0.007, 0.18)
# Final Results (AVG): ('NO2.3(t+1)', 0.718, 0.859, 0.523, 0.249, 0.006, 0.957)
# Final Results (STD): ('NO2.3(t+1)', 0.491, 2.248, 0.573, 0.259, 0.004, 0.118)
# Final Results (AVG): ('CO.3(t+1)', 15.659, 24.878, 0.653, 0.301, 0.006, 0.946)
# Final Results (STD): ('CO.3(t+1)', 10.984, 55.218, 0.904, 0.391, 0.004, 0.123)
# Final Results (AVG): ('O3.3(t+1)', 0.889, 12.146, 1.861, 0.672, 0.006, 0.884)
# Final Results (STD): ('O3.3(t+1)', 0.589, 47.769, 3.236, 0.992, 0.005, 0.277)
# Final Results (AVG): ('TEMP.3(t+1)', 44.452, 122.561, inf, 4.299, 2.385, -1392.874)
# Final Results (STD): ('TEMP.3(t+1)', 157.938, 590.196, nan, 9.62, 9.161, 5399.851)
# Final Results (AVG): ('PRES.3(t+1)', 77.31, 16.803, 1.642, 0.203, 2.253, -2284.216)
# Final Results (STD): ('PRES.3(t+1)', 420.435, 90.854, 8.879, 1.053, 12.148, 12516.477)
# Final Results (AVG): ('DEWP.3(t+1)', 0.094, 0.846, inf, 0.343, 0.005, 0.795)
# Final Results (STD): ('DEWP.3(t+1)', 0.057, 2.194, nan, 0.532, 0.003, 0.403)
# Final Results (AVG): ('RAIN.3(t+1)', 0.017, 0.024, nan, nan, 0.015, 0.38)
# Final Results (STD): ('RAIN.3(t+1)', 0.027, 0.052, nan, nan, 0.041, 0.709)
# Final Results (AVG): ('WSPM.3(t+1)', 0.056, 0.02, inf, 0.56, 0.009, 0.973)
# Final Results (STD): ('WSPM.3(t+1)', 0.035, 0.031, nan, 0.302, 0.005, 0.079)
# Final Results (AVG): ('PM2.5.4(t+1)', 1.179, 5.392, 1.23, 0.492, 0.005, 0.858)
# Final Results (STD): ('PM2.5.4(t+1)', 0.866, 12.764, 2.116, 0.743, 0.005, 0.283)
# Final Results (AVG): ('PM10.4(t+1)', 2.157, 4.916, 1.239, 0.496, 0.007, 0.89)
# Final Results (STD): ('PM10.4(t+1)', 1.82, 11.967, 1.92, 0.632, 0.006, 0.238)
# Final Results (AVG): ('SO2.4(t+1)', 0.615, 0.774, 2.968, 0.936, 0.009, 0.884)
# Final Results (STD): ('SO2.4(t+1)', 1.631, 1.389, 6.514, 1.442, 0.01, 0.211)
# Final Results (AVG): ('NO2.4(t+1)', 0.709, 40.942, 0.533, 0.243, 0.005, 0.91)
# Final Results (STD): ('NO2.4(t+1)', 0.423, 217.25, 0.52, 0.217, 0.004, 0.254)
# Final Results (AVG): ('CO.4(t+1)', 16.22, 34.678, 0.68, 0.286, 0.006, 0.925)
# Final Results (STD): ('CO.4(t+1)', 12.315, 71.636, 1.094, 0.389, 0.005, 0.157)
# Final Results (AVG): ('O3.4(t+1)', 1.101, 32.221, 3.02, 0.947, 0.007, 0.92)
# Final Results (STD): ('O3.4(t+1)', 1.312, 170.683, 3.911, 1.12, 0.011, 0.214)
# Final Results (AVG): ('TEMP.4(t+1)', 44.457, 122.54, inf, 4.109, 2.386, -1392.872)
# Final Results (STD): ('TEMP.4(t+1)', 157.937, 590.2, nan, 9.523, 9.161, 5399.852)
# Final Results (AVG): ('PRES.4(t+1)', 77.31, 16.801, 1.642, 0.203, 2.252, -2284.217)
# Final Results (STD): ('PRES.4(t+1)', 420.435, 90.855, 8.879, 1.053, 12.148, 12516.477)
# Final Results (AVG): ('DEWP.4(t+1)', 0.092, 0.82, inf, 0.317, 0.005, 0.787)
# Final Results (STD): ('DEWP.4(t+1)', 0.055, 1.97, nan, 0.636, 0.003, 0.395)
# Final Results (AVG): ('RAIN.4(t+1)', 0.016, 0.023, nan, nan, 0.013, 0.501)
# Final Results (STD): ('RAIN.4(t+1)', 0.023, 0.052, nan, nan, 0.031, 0.525)
# Final Results (AVG): ('WSPM.4(t+1)', 0.055, 0.02, inf, 1.319, 0.011, 0.969)
# Final Results (STD): ('WSPM.4(t+1)', 0.039, 0.033, nan, 2.916, 0.01, 0.083)
# Final Results (AVG): ('PM2.5.5(t+1)', 1.043, 4.951, 1.172, 0.491, 0.005, 0.862)
# Final Results (STD): ('PM2.5.5(t+1)', 0.842, 11.559, 1.937, 0.737, 0.005, 0.263)
# Final Results (AVG): ('PM10.5(t+1)', 2.667, 2.958, 1.232, 0.52, 0.008, 0.94)
# Final Results (STD): ('PM10.5(t+1)', 1.561, 7.219, 1.584, 0.599, 0.006, 0.147)
# Final Results (AVG): ('SO2.5(t+1)', 0.3, 1.094, 2.277, 0.852, 0.01, 0.832)
# Final Results (STD): ('SO2.5(t+1)', 0.292, 3.183, 4.581, 1.376, 0.012, 0.315)
# Final Results (AVG): ('NO2.5(t+1)', 0.749, 0.654, 0.595, 0.249, 0.005, 0.959)
# Final Results (STD): ('NO2.5(t+1)', 0.436, 1.189, 0.806, 0.242, 0.004, 0.076)
# Final Results (AVG): ('CO.5(t+1)', 27.013, 34.267, 0.653, 0.277, 0.009, 0.933)
# Final Results (STD): ('CO.5(t+1)', 55.228, 81.472, 0.772, 0.28, 0.013, 0.165)
# Final Results (AVG): ('O3.5(t+1)', 1.126, 82.8, 2.489, 0.79, 0.007, 0.899)
# Final Results (STD): ('O3.5(t+1)', 1.307, 447.221, 5.695, 1.469, 0.008, 0.239)
# Final Results (AVG): ('TEMP.5(t+1)', 16.196, 97.126, inf, 2.734, 0.636, -122.311)
# Final Results (STD): ('TEMP.5(t+1)', 51.055, 508.761, nan, 7.591, 2.443, 522.499)
# Final Results (AVG): ('PRES.5(t+1)', 0.548, 0.205, 0.02, 0.01, 0.034, 0.969)
# Final Results (STD): ('PRES.5(t+1)', 0.275, 0.125, 0.012, 0.006, 0.02, 0.034)
# Final Results (AVG): ('DEWP.5(t+1)', 0.07, 0.755, inf, 0.321, 0.004, 0.798)
# Final Results (STD): ('DEWP.5(t+1)', 0.045, 1.876, nan, 0.47, 0.003, 0.383)
# Final Results (AVG): ('RAIN.5(t+1)', 0.032, 0.026, nan, nan, 0.022, 0.058)
# Final Results (STD): ('RAIN.5(t+1)', 0.066, 0.073, nan, nan, 0.074, 2.359)
# Final Results (AVG): ('WSPM.5(t+1)', 0.04, 0.019, inf, 1.374, 0.01, 0.973)
# Final Results (STD): ('WSPM.5(t+1)', 0.023, 0.033, nan, 2.154, 0.007, 0.064)

# %%
pd.set_option('display.max_rows', None)
metrics_measures_kpca.head(20)
# Out:
#     window     time_step    rmse   mape   smape       mae     r2     fb  \
# 0        0    PM2.5(t+1)   0.370  0.156   0.079     0.082  1.000 -0.000
# 1        0     PM10(t+1)   0.963  0.258   0.127     0.220  1.000 -0.001
# 2        0      SO2(t+1)   0.288  0.297   0.153     0.058  1.000  0.001
# 3        0      NO2(t+1)   1.715  0.472   0.240     0.306  0.996 -0.000
# 4        0       CO(t+1)  16.233  0.470   0.227     3.502  0.997 -0.001
# 5        0       O3(t+1)   0.455  4.041   0.480  1419.627 -0.021  1.867
# 6        0     TEMP(t+1)   0.097  0.286   0.143     0.024  1.000  0.000
# 7        0     PRES(t+1)   0.308  0.012   0.006     0.121  0.998  0.000
# 8        0     DEWP(t+1)   0.163    inf   1.531     0.103  0.981 -0.031
# 9        0     RAIN(t+1)   0.003    inf  33.333     0.000  0.954 -0.147
# 10       0     WSPM(t+1)   0.077  0.635   0.289     0.011  0.997 -0.002
# 11       0  PM2.5.1(t+1)   0.199  0.093   0.047     0.038  1.000  0.000
# 12       0   PM10.1(t+1)   0.433  0.108   0.053     0.086  1.000 -0.000
# 13       0    SO2.1(t+1)   0.599  0.778   0.339     0.094  0.998 -0.002
# 14       0    NO2.1(t+1)   0.883  3.391   1.038     0.211  0.998 -0.003
# 15       0     CO.1(t+1)  19.592  2.513   1.079     5.929  0.997 -0.009
# 16       0     O3.1(t+1)   0.327  0.082   0.043  2028.135 -0.036  1.870
# 17       0   TEMP.1(t+1)   0.092  0.227   0.110     0.018  1.000 -0.001
# 18       0   PRES.1(t+1)   0.301  0.011   0.006     0.116  0.998  0.000
# 19       0   DEWP.1(t+1)   0.033  0.496   0.253     0.150  0.949 -0.029
#
#     nrmse  rules  time_cost  mem_cost
# 0   0.001   7136  62.867748  0.675404
# 1   0.003   7238  62.867748  0.675404
# 2   0.003   7235  62.867748  0.675404
# 3   0.014   7307  62.867748  0.675404
# 4   0.011   7152  62.867748  0.675404
# 5   0.000   6953  62.867748  0.675404
# 6   0.004   7397  62.867748  0.675404
# 7   0.011   6070  62.867748  0.675404
# 8   0.007   7218  62.867748  0.675404
# 9   0.017   3127  62.867748  0.675404
# 10  0.011   7913  62.867748  0.675404
# 11  0.001   6970  62.867748  0.675404
# 12  0.001   6980  62.867748  0.675404
# 13  0.008   7099  62.867748  0.675404
# 14  0.011   7293  62.867748  0.675404
# 15  0.012   7147  62.867748  0.675404
# 16  0.000   6900  62.867748  0.675404
# 17  0.004   7444  62.867748  0.675404
# 18  0.011   6089  62.867748  0.675404
# 19  0.001   7146  62.867748  0.675404

# %%
final_metrics_measures_kpca
# Out:
#        time_step    rmse      mae   mape        r2  smape  nrmse     fb  \
# 0     PM2.5(t+1)   1.051    5.443  1.175     0.860  0.506  0.005  0.053
# 1      PM10(t+1)   2.037    6.173  1.256     0.873  0.528  0.007  0.038
# 2       SO2(t+1)   0.257    0.433  1.115     0.934  0.471  0.008  0.012
# 3       NO2(t+1)   0.762    0.649  0.472     0.974  0.203  0.006  0.005
# 4        CO(t+1)  15.354   34.334  0.905     0.917  0.333  0.005  0.020
# 5        O3(t+1)   0.978   48.500  3.006     0.918  0.980  0.006  0.076
# 6      TEMP(t+1)  44.457  122.540    inf -1392.872  4.109  2.386  0.004
# 7      PRES(t+1)  77.310   16.801  1.642 -2284.217  0.203  2.252 -0.013
# 8      DEWP(t+1)   0.092    0.820    inf     0.787  0.317  0.005  0.796
# 9      RAIN(t+1)   0.016    0.023    NaN     0.501    NaN  0.013    NaN
# 10     WSPM(t+1)   0.055    0.020    inf     0.970  1.305  0.011  0.003
# 11  PM2.5.1(t+1)   0.956    3.189  1.327     0.912  0.568  0.005  0.036
# 12   PM10.1(t+1)   1.971    3.747  1.102     0.905  0.511  0.007  0.025
# 13    SO2.1(t+1)   0.369    0.464  2.999     0.879  1.066  0.010  0.022
# 14    NO2.1(t+1)   0.661    0.401  0.856     0.974  0.342  0.006  0.003
# 15     CO.1(t+1)  23.045   24.399  0.900     0.925  0.403  0.007  0.018
# 16     O3.1(t+1)   0.894   68.368  1.534     0.922  0.583  0.006  0.075
# 17   TEMP.1(t+1)  34.223   66.124    inf  -603.916  3.948  1.475  0.065
# 18   PRES.1(t+1)   0.531    0.206  0.020     0.970  0.010  0.033  0.000
# 19   DEWP.1(t+1)   0.073    0.777    inf     0.814  0.542  0.004 -0.186
# 20   RAIN.1(t+1)   0.018    0.009    NaN     0.606    NaN  0.007    NaN
# 21   WSPM.1(t+1)   0.059    0.021    inf     0.969  0.621  0.010  0.002
# 22  PM2.5.2(t+1)   1.437    4.506  1.537     0.884  0.624  0.007  0.057
# 23   PM10.2(t+1)   1.946    3.641  1.675     0.896  0.660  0.009  0.028
# 24    SO2.2(t+1)   0.272    0.247  3.059     0.931  1.061  0.008  0.005
# 25    NO2.2(t+1)   0.382    0.706  0.989     0.942  0.406  0.005  0.017
# 26     CO.2(t+1)  16.256   23.766  1.025     0.913  0.462  0.006  0.015
# 27     O3.2(t+1)   0.910   94.844  0.912     0.941  0.395  0.006  0.068
# 28   TEMP.2(t+1)  34.223   66.124    inf  -603.916  3.948  1.475  0.065
# 29   PRES.2(t+1)  77.094   16.865  1.657 -2252.285  0.207  2.252 -0.013
# 30   DEWP.2(t+1)   0.073    0.777    inf     0.814  0.542  0.004 -0.186
# 31   RAIN.2(t+1)   0.018    0.009    NaN     0.606    NaN  0.007    NaN
# 32   WSPM.2(t+1)   0.055    0.021    inf     0.970  0.593  0.009  0.002
# 33  PM2.5.3(t+1)   1.235    4.836  1.440     0.887  0.567  0.005  0.045
# 34   PM10.3(t+1)   2.127    4.622  1.424     0.900  0.535  0.007  0.029
# 35    SO2.3(t+1)   0.295    0.481  1.504     0.927  0.625  0.007  0.017
# 36    NO2.3(t+1)   0.718    0.859  0.523     0.957  0.249  0.006  0.008
# 37     CO.3(t+1)  15.659   24.878  0.653     0.946  0.301  0.006  0.012
# 38     O3.3(t+1)   0.889   12.146  1.861     0.884  0.672  0.006  0.078
# 39   TEMP.3(t+1)  44.452  122.561    inf -1392.874  4.299  2.385  0.010
# 40   PRES.3(t+1)  77.310   16.803  1.642 -2284.216  0.203  2.253 -0.013
# 41   DEWP.3(t+1)   0.094    0.846    inf     0.795  0.343  0.005  0.749
# 42   RAIN.3(t+1)   0.017    0.024    NaN     0.380    NaN  0.015    NaN
# 43   WSPM.3(t+1)   0.056    0.020    inf     0.973  0.560  0.009  0.003
# 44  PM2.5.4(t+1)   1.179    5.392  1.230     0.858  0.492  0.005  0.053
# 45   PM10.4(t+1)   2.157    4.916  1.239     0.890  0.496  0.007  0.033
# 46    SO2.4(t+1)   0.615    0.774  2.968     0.884  0.936  0.009  0.025
# 47    NO2.4(t+1)   0.709   40.942  0.533     0.910  0.243  0.005  0.072
# 48     CO.4(t+1)  16.220   34.678  0.680     0.925  0.286  0.006  0.019
# 49     O3.4(t+1)   1.101   32.221  3.020     0.920  0.947  0.007  0.071
# 50   TEMP.4(t+1)  44.457  122.540    inf -1392.872  4.109  2.386  0.004
# 51   PRES.4(t+1)  77.310   16.801  1.642 -2284.217  0.203  2.252 -0.013
# 52   DEWP.4(t+1)   0.092    0.820    inf     0.787  0.317  0.005  0.796
# 53   RAIN.4(t+1)   0.016    0.023    NaN     0.501    NaN  0.013    NaN
# 54   WSPM.4(t+1)   0.055    0.020    inf     0.969  1.319  0.011  0.003
# 55  PM2.5.5(t+1)   1.043    4.951  1.172     0.862  0.491  0.005  0.046
# 56   PM10.5(t+1)   2.667    2.958  1.232     0.940  0.520  0.008  0.013
# 57    SO2.5(t+1)   0.300    1.094  2.277     0.832  0.852  0.010  0.053
# 58    NO2.5(t+1)   0.749    0.654  0.595     0.959  0.249  0.005  0.006
# 59     CO.5(t+1)  27.013   34.267  0.653     0.933  0.277  0.009  0.017
# 60     O3.5(t+1)   1.126   82.800  2.489     0.899  0.790  0.007  0.085
# 61   TEMP.5(t+1)  16.196   97.126    inf  -122.311  2.734  0.636  0.344
# 62   PRES.5(t+1)   0.548    0.205  0.020     0.969  0.010  0.034  0.000
# 63   DEWP.5(t+1)   0.070    0.755    inf     0.798  0.321  0.004  0.179
# 64   RAIN.5(t+1)   0.032    0.026    NaN     0.058    NaN  0.022    NaN
# 65   WSPM.5(t+1)   0.040    0.019    inf     0.973  1.374  0.010  0.003
#
#         rules  time_cost  ...  rmse_std  mae_std  mape_std     r2_std  \
# 0    6642.967    231.344  ...     0.898   12.303     1.684      0.273
# 1    6921.900    231.344  ...     1.162   14.100     1.228      0.262
# 2    6750.967    231.344  ...     0.237    1.236     1.124      0.178
# 3    7268.400    231.344  ...     0.507    1.926     0.606      0.098
# 4    6851.933    231.344  ...    13.965   92.224     1.596      0.183
# 5    6890.433    231.344  ...     0.644  258.979     5.595      0.220
# 6    7042.533    231.344  ...   157.937  590.200       NaN   5399.852
# 7    5588.667    231.344  ...   420.435   90.855     8.879  12516.477
# 8    6916.300    231.344  ...     0.055    1.970       NaN      0.395
# 9    7254.267    231.344  ...     0.023    0.052       NaN      0.525
# 10   7613.100    231.344  ...     0.037    0.032       NaN      0.083
# 11   6728.467    231.344  ...     0.660    8.984     1.969      0.216
# 12   6963.467    231.344  ...     1.401    9.470     1.258      0.210
# 13   6690.200    231.344  ...     0.272    1.352     5.814      0.240
# 14   7419.033    231.344  ...     0.384    1.170     0.977      0.101
# 15   6937.967    231.344  ...    30.098   45.078     0.967      0.167
# 16   7110.633    231.344  ...     0.675  370.143     2.023      0.204
# 17   7071.833    231.344  ...   116.753  285.462       NaN   2541.430
# 18   5591.800    231.344  ...     0.227    0.117     0.012      0.034
# 19   6895.167    231.344  ...     0.065    2.180       NaN      0.404
# 20  11319.433    231.344  ...     0.037    0.019       NaN      0.598
# 21   7652.367    231.344  ...     0.037    0.026       NaN      0.104
# 22   6648.900    231.344  ...     2.415   11.944     2.218      0.266
# 23   6865.000    231.344  ...     1.335    9.746     2.188      0.219
# 24   6639.467    231.344  ...     0.258    0.766     9.356      0.175
# 25   7087.300    231.344  ...     0.279    2.399     1.818      0.162
# 26   6735.567    231.344  ...    14.595   42.831     1.331      0.169
# 27   6932.433    231.344  ...     0.718  516.043     1.339      0.198
# 28   7071.833    231.344  ...   116.753  285.462       NaN   2541.430
# 29   5580.600    231.344  ...   419.304   91.221     8.959  12341.579
# 30   6895.167    231.344  ...     0.065    2.180       NaN      0.404
# 31  11319.433    231.344  ...     0.037    0.019       NaN      0.598
# 32   7652.367    231.344  ...     0.030    0.025       NaN      0.103
# 33   6689.767    231.344  ...     1.314   11.912     2.482      0.261
# 34   6936.767    231.344  ...     1.587    9.391     2.022      0.211
# 35   6681.600    231.344  ...     0.307    1.226     2.118      0.180
# 36   7230.267    231.344  ...     0.491    2.248     0.573      0.118
# 37   6882.700    231.344  ...    10.984   55.218     0.904      0.123
# 38   6940.067    231.344  ...     0.589   47.769     3.236      0.277
# 39   7050.867    231.344  ...   157.938  590.196       NaN   5399.851
# 40   5572.933    231.344  ...   420.435   90.854     8.879  12516.477
# 41   6891.800    231.344  ...     0.057    2.194       NaN      0.403
# 42   5133.200    231.344  ...     0.027    0.052       NaN      0.709
# 43   7633.033    231.344  ...     0.035    0.031       NaN      0.079
# 44   6714.133    231.344  ...     0.866   12.764     2.116      0.283
# 45   6911.433    231.344  ...     1.820   11.967     1.920      0.238
# 46   6648.167    231.344  ...     1.631    1.389     6.514      0.211
# 47   7229.167    231.344  ...     0.423  217.250     0.520      0.254
# 48   6856.033    231.344  ...    12.315   71.636     1.094      0.157
# 49   6870.500    231.344  ...     1.312  170.683     3.911      0.214
# 50   7042.533    231.344  ...   157.937  590.200       NaN   5399.852
# 51   5588.667    231.344  ...   420.435   90.855     8.879  12516.477
# 52   6916.300    231.344  ...     0.055    1.970       NaN      0.395
# 53   7254.267    231.344  ...     0.023    0.052       NaN      0.525
# 54   7613.100    231.344  ...     0.039    0.033       NaN      0.083
# 55   6751.133    231.344  ...     0.842   11.559     1.937      0.263
# 56   6999.867    231.344  ...     1.561    7.219     1.584      0.147
# 57   6527.000    231.344  ...     0.292    3.183     4.581      0.315
# 58   7308.267    231.344  ...     0.436    1.189     0.806      0.076
# 59   6961.933    231.344  ...    55.228   81.472     0.772      0.165
# 60   7005.333    231.344  ...     1.307  447.221     5.695      0.239
# 61   7070.367    231.344  ...    51.055  508.761       NaN    522.499
# 62   5592.600    231.344  ...     0.275    0.125     0.012      0.034
# 63   6853.367    231.344  ...     0.045    1.876       NaN      0.383
# 64  13967.500    231.344  ...     0.066    0.073       NaN      2.359
# 65   7477.033    231.344  ...     0.023    0.033       NaN      0.064
#
#     smape_std  nrmse_std  fb_std  rules_std  time_cost_std  mem_cost_std
# 0       0.664      0.005   0.115    769.577        577.649         2.491
# 1       0.498      0.006   0.091    742.635        577.649         2.491
# 2       0.433      0.010   0.049    531.158        577.649         2.491
# 3       0.205      0.004   0.020    657.504        577.649         2.491
# 4       0.424      0.004   0.058    654.986        577.649         2.491
# 5       1.629      0.004   0.341    698.150        577.649         2.491
# 6       9.523      9.161   0.782    903.973        577.649         2.491
# 7       1.053     12.148   0.072    714.364        577.649         2.491
# 8       0.636      0.003   4.661    601.190        577.649         2.491
# 9         NaN      0.031     NaN  16564.491        577.649         2.491
# 10      2.969      0.010   0.017    517.161        577.649         2.491
# 11      0.764      0.004   0.102    672.230        577.649         2.491
# 12      0.566      0.006   0.075    694.065        577.649         2.491
# 13      1.597      0.010   0.078    551.385        577.649         2.491
# 14      0.319      0.004   0.022    605.742        577.649         2.491
# 15      0.406      0.007   0.049    523.436        577.649         2.491
# 16      0.625      0.004   0.341    646.408        577.649         2.491
# 17      9.853      5.824   0.977    922.789        577.649         2.491
# 18      0.006      0.019   0.000    710.102        577.649         2.491
# 19      1.020      0.003   0.879    590.638        577.649         2.491
# 20        NaN      0.023     NaN  21672.454        577.649         2.491
# 21      0.397      0.007   0.016    535.096        577.649         2.491
# 22      0.822      0.015   0.161    730.566        577.649         2.491
# 23      0.722      0.011   0.080    686.537        577.649         2.491
# 24      2.491      0.008   0.058    514.650        577.649         2.491
# 25      0.588      0.004   0.060    703.332        577.649         2.491
# 26      0.543      0.005   0.039    523.226        577.649         2.491
# 27      0.517      0.006   0.346    716.253        577.649         2.491
# 28      9.853      5.824   0.977    922.789        577.649         2.491
# 29      1.077     12.150   0.072    723.201        577.649         2.491
# 30      1.020      0.003   0.879    590.638        577.649         2.491
# 31        NaN      0.023     NaN  21672.454        577.649         2.491
# 32      0.356      0.006   0.015    535.096        577.649         2.491
# 33      0.841      0.006   0.117    798.002        577.649         2.491
# 34      0.644      0.006   0.067    763.551        577.649         2.491
# 35      0.794      0.007   0.064    622.517        577.649         2.491
# 36      0.259      0.004   0.027    643.387        577.649         2.491
# 37      0.391      0.004   0.033    582.930        577.649         2.491
# 38      0.992      0.005   0.256    792.201        577.649         2.491
# 39      9.620      9.161   0.782    908.898        577.649         2.491
# 40      1.053     12.148   0.072    719.685        577.649         2.491
# 41      0.532      0.003   4.704    592.353        577.649         2.491
# 42        NaN      0.041     NaN  12326.755        577.649         2.491
# 43      0.302      0.005   0.016    529.116        577.649         2.491
# 44      0.743      0.005   0.120    823.406        577.649         2.491
# 45      0.632      0.006   0.086    800.692        577.649         2.491
# 46      1.442      0.010   0.078    556.446        577.649         2.491
# 47      0.217      0.004   0.341    668.228        577.649         2.491
# 48      0.389      0.005   0.044    580.899        577.649         2.491
# 49      1.120      0.011   0.320    827.776        577.649         2.491
# 50      9.523      9.161   0.782    903.973        577.649         2.491
# 51      1.053     12.148   0.072    714.364        577.649         2.491
# 52      0.636      0.003   4.661    601.190        577.649         2.491
# 53        NaN      0.031     NaN  16564.491        577.649         2.491
# 54      2.916      0.010   0.018    517.161        577.649         2.491
# 55      0.737      0.005   0.111    806.429        577.649         2.491
# 56      0.599      0.006   0.042    767.027        577.649         2.491
# 57      1.376      0.012   0.192    620.966        577.649         2.491
# 58      0.242      0.004   0.014    676.543        577.649         2.491
# 59      0.280      0.013   0.054    584.102        577.649         2.491
# 60      1.469      0.008   0.349    730.847        577.649         2.491
# 61      7.591      2.443   2.052    945.816        577.649         2.491
# 62      0.006      0.020   0.000    700.667        577.649         2.491
# 63      0.470      0.003   1.635    600.604        577.649         2.491
# 64        NaN      0.074     NaN  25102.409        577.649         2.491
# 65      2.154      0.007   0.014    515.987        577.649         2.491
#
# [66 rows x 21 columns]

# %%
metrics_measures_kpca.to_csv (r'aec_metrics_measures_kpca_parallel.csv', index = False, header=True)
final_metrics_measures_kpca.to_csv (r'aec_final_metrics_measures_kpca_parallel.csv', index = False, header=True)

# %%
import math
import statistics

# %%
round(statistics.mean(final_metrics_measures_kpca['nrmse']),3)
# Out:
# 0.306

# %% [markdown]
# ## ==================================

# %% [markdown]
# ## ==================================

# %% [markdown]
# ## ==================================

# %% [markdown]
# ## ==================================
